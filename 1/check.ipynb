# %%
from defs import load_stock_price
import pandas as pd
import numpy as np


company_ticker = '005930'
term = 120

# 매수신호
company_data = pd.DataFrame(load_stock_price(company_ticker, company_ticker, term))
company_data['signal'] = np.where(company_data['MA_5'] > company_data['MA_20'], 1, -1)
company_data = company_data[19:]
change = (company_data['signal']==1) & (company_data['signal'].shift(1) == -1)
golden_cross = company_data[change]


# 매도 신호
company_data = pd.DataFrame(load_stock_price(company_ticker, company_ticker, term))
company_data['signal'] = np.where(company_data['MA_5'] > company_data['MA_20'], 1, -1)
company_data = company_data[19:]
change = (company_data['signal']==-1) & (company_data['signal'].shift(1) == 1)
dead_cross = company_data[change]
dead_cross.index
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Change'], dtype='object')
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Change'], dtype='object')
# DatetimeIndex(['2026-03-12', '2026-03-27'], dtype='datetime64[ns]', name='Date', freq=None)
